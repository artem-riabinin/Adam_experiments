# %%
import matplotlib.pyplot as plt
import re

# Function to parse the log file and extract epoch and train loss values
def parse_log_file(log_file_path):
    epochs = []
    train_losses = []
    
    # Open the log file and read the lines
    with open(log_file_path, 'r') as file:
        lines = file.readlines()
        
        # Regular expression to match the epoch and train loss in each line
        pattern = r"Epoch \[(\d+)/\d+\], Train Loss: ([\d.]+)"
        
        for line in lines:
            match = re.search(pattern, line)
            if match:
                epoch = int(match.group(1))
                train_loss = float(match.group(2))
                epochs.append(epoch)
                train_losses.append(train_loss)
    
    return epochs, train_losses

# Function to plot the train loss vs. epochs for multiple log files
def plot_multiple_train_losses(log_file_paths):
    plt.figure(figsize=(10, 6))
    
    # Iterate over each log file and plot its data
    k = 0
    for log_file_path in log_file_paths:
        epochs, train_losses = parse_log_file(log_file_path)
        if k == 0:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0$, $\beta_2 = 0.999$, $\alpha = 0.001$', marker='o', markersize=2, linewidth=1)
        if k == 1:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0$, $\beta_2 = 0.5$, $\alpha = 0.001$', marker='o', markersize=2, linewidth=1)
        if k == 2:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0$, $\beta_2 = 0.1$, $\alpha = 0.001$', marker='o', markersize=2, linewidth=1)
        k+=1
    
    # Customize the plot
    plt.xlabel('Epoch', fontsize=16)
    plt.ylabel('Train Loss', fontsize=16)
    plt.grid(True)
    plt.xlim([0, 550])
    plt.ylim([0, 2])
    plt.legend(fontsize=14)
    plt.savefig('resnet_exp_1.pdf', format='pdf')
    plt.show()

# Main function
if __name__ == "__main__":
    log_file_paths = [
        'output3.txt',  
        'output2.txt',
        'output1.txt'
    ]
    
    # Plot train loss vs epochs for all log files
    plot_multiple_train_losses(log_file_paths)

# %%
import matplotlib.pyplot as plt
import re

# Function to parse the log file and extract epoch and train loss values
def parse_log_file(log_file_path):
    epochs = []
    train_losses = []
    
    # Open the log file and read the lines
    with open(log_file_path, 'r') as file:
        lines = file.readlines()
        
        # Regular expression to match the epoch and train loss in each line
        pattern = r"Epoch \[(\d+)/\d+\], Train Loss: ([\d.]+)"
        
        for line in lines:
            match = re.search(pattern, line)
            if match:
                epoch = int(match.group(1))
                train_loss = float(match.group(2))
                epochs.append(epoch)
                train_losses.append(train_loss)
    
    return epochs, train_losses

# Function to plot the train loss vs. epochs for multiple log files
def plot_multiple_train_losses(log_file_paths):
    plt.figure(figsize=(10, 6))
    
    # Iterate over each log file and plot its data
    k = 0
    for log_file_path in log_file_paths:
        epochs, train_losses = parse_log_file(log_file_path)
        if k == 0:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0.9$, $\beta_2 = 0.999$, $\alpha = 0.002$', marker='o', markersize=1, linewidth=1)
        if k == 1:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0.9$, $\beta_2 = 0.5$, $\alpha = 0.001$', marker='o', markersize=1, linewidth=1)
        if k == 2:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0.9$, $\beta_2 = 0.1$, $\alpha = 0.0005$', marker='o', markersize=1, linewidth=1)
        k+=1
    
    # Customize the plot
    plt.xlabel('Epoch', fontsize=16)
    plt.ylabel('Train Loss', fontsize=16)
    plt.grid(True)
    plt.ylim([-0.1, 2.7])
    plt.legend(fontsize=14)
    plt.savefig('resnet_exp_2.pdf', format='pdf')
    plt.show()

# Main function
if __name__ == "__main__":
    log_file_paths = [
        'output4.txt',  
        'output5.txt',
        'output6.txt'
    ]
    
    # Plot train loss vs epochs for all log files
    plot_multiple_train_losses(log_file_paths)

# %%
import matplotlib.pyplot as plt
import re

# Function to parse the log file and extract epoch and train loss values
def parse_log_file(log_file_path):
    epochs = []
    train_losses = []
    
    # Open the log file and read the lines
    with open(log_file_path, 'r') as file:
        lines = file.readlines()
        
        # Regular expression to match the epoch and train loss in each line
        pattern = r"\| epoch\s+(\d+)\s+\| total loss ([\d.]+) \|"
        
        for line in lines:
            match = re.search(pattern, line)
            if match:
                epoch = int(match.group(1))
                train_loss = float(match.group(2))
                epochs.append(epoch)
                train_losses.append(train_loss)
    
    return epochs, train_losses

# Function to plot the train loss vs. epochs for multiple log files
def plot_multiple_train_losses(log_file_paths):
    plt.figure(figsize=(10, 6))
    
    # Iterate over each log file and plot its data
    k = 0
    for log_file_path in log_file_paths:
        epochs, train_losses = parse_log_file(log_file_path)
        if k == 0:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0$, $\beta_2 = 0.999$, $\alpha = 0.005$', marker='o', markersize=1, linewidth=0.8)
        if k == 1:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0$, $\beta_2 = 0.5$, $\alpha = 0.005$', marker='o', markersize=1, linewidth=0.8)
        if k == 2:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0$, $\beta_2 = 0.1$, $\alpha = 0.005$', marker='o', markersize=1, linewidth=0.8)
        k+=1
    
    # Customize the plot
    plt.xlabel('Epoch', fontsize=16)
    plt.ylabel('Train Loss', fontsize=16)
    plt.grid(True)
    plt.ylim([1, 6])
    plt.xlim([0, 3050])
    plt.legend(fontsize=14)
    plt.savefig('lstm_exp_1.pdf', format='pdf')
    plt.show()

# Main function
if __name__ == "__main__":
    log_file_paths = [
        'output33.txt',  
        'output22.txt',
        'output11.txt'
    ]
    
    # Plot train loss vs epochs for all log files
    plot_multiple_train_losses(log_file_paths)

# %%
import matplotlib.pyplot as plt
import re

# Function to parse the log file and extract epoch and train loss values
def parse_log_file(log_file_path):
    epochs = []
    train_losses = []
    
    # Open the log file and read the lines
    with open(log_file_path, 'r') as file:
        lines = file.readlines()
        
        # Regular expression to match the epoch and train loss in each line
        pattern = r"\| epoch\s+(\d+)\s+\| total loss ([\d.]+) \|"
        
        for line in lines:
            match = re.search(pattern, line)
            if match:
                epoch = int(match.group(1))
                train_loss = float(match.group(2))
                epochs.append(epoch)
                train_losses.append(train_loss)
    
    return epochs, train_losses

# Function to plot the train loss vs. epochs for multiple log files
def plot_multiple_train_losses(log_file_paths):
    plt.figure(figsize=(10, 6))
    
    # Iterate over each log file and plot its data
    k = 0
    for log_file_path in log_file_paths:
        epochs, train_losses = parse_log_file(log_file_path)
        if k == 0:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0.9$, $\beta_2 = 0.999$, $\alpha = 0.02$', marker='o', markersize=1, linewidth=0.8)
        if k == 1:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0.9$, $\beta_2 = 0.5$, $\alpha = 0.005$', marker='o', markersize=1, linewidth=0.8)
        if k == 2:
            plt.plot(epochs, train_losses, label=r'Adam: $\beta_1 = 0.9$, $\beta_2 = 0.1$, $\alpha = 0.001$', marker='o', markersize=1, linewidth=0.8)
        k+=1
    
    # Customize the plot
    plt.xlabel('Epoch', fontsize=16)
    plt.ylabel('Train Loss', fontsize=16)
    plt.grid(True)
    plt.ylim([1.3, 6.5])
    plt.xlim([0, 3000])
    plt.legend(fontsize=14)
    plt.savefig('lstm_exp_2.pdf', format='pdf')
    plt.show()

# Main function
if __name__ == "__main__":
    log_file_paths = [
        'out6.txt',  
        'out5.txt',
        'out4.txt'
    ]
    
    # Plot train loss vs epochs for all log files
    plot_multiple_train_losses(log_file_paths)
